# %%
import pandas as pd
album_sales = pd.read_csv('albumsales.csv')

album_sales.info()
print(album_sales)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    375 non-null    float64
#  1   Ranking                 320 non-null    float64
#  2   Artist                  375 non-null    object
#  3   Album                   375 non-null    object
#  4   Worldwide Sales (Est.)  375 non-null    object
#  5   CDs                     375 non-null    float64
#  6   Tracks                  375 non-null    float64
#  7   Album Length            375 non-null    object
#  8   Hours                   375 non-null    float64
#  9   Minutes                 375 non-null    float64
#  10  Seconds                 375 non-null    float64
#  11  Genre                   375 non-null    object
# dtypes: float64(7), object(5)
# memory usage: 36.7+ KB
#        Year  Ranking               Artist  \
# ...

# %%
new_albumSales= album_sales.drop(columns=['Tracks', 'CDs', 'Album Length', 
                                          'Hours', 'Minutes', 'Seconds', 'Ranking' ])


new_albumSales.to_csv('newalbumSales.csv', index=False)
new_albumSales = pd.read_csv('new_albumSales.csv')



new_albumSales
# Out:
#      Year               Artist                                   Album  \
# 0    2019               Arashi           5x20 All The Best!! 1999-2019
# 1    2017           Elton John                                Diamonds
# 2    1995      Michael Jackson  History: Past, Present & Future Book I
# 3    2015  Broadway Soundtrack                                Hamilton
# 4    2003              Outkast           Speakerboxxx / The Love Below
# ..    ...                  ...                                     ...
# 370  2011         David Guetta                    Nothing But The Beat
# 371  2010          Susan Boyle                                The Gift
# 372  2010                 P!NK                    Greatest Hits So Far
# 373  2010                Drake                          Thank Me Later
# 374  2010          Nicki Minaj                             Pink Friday
#
#     Worldwide Sales (Est.)      Genre
# 0                3,300,000        Pop
# ...

# %%
# SQL 
# SELECT 
# 	"Year", 
# 	"Album", 
# 	"WorldwideSales(Est.)"
# From new_albumsales
# ORDER BY YEAR ASC

#Deleting rows from before 2010
# DELETE 
# FROM new_albumsales
# WHERE YEAR < 2010;

# DELETE
# FROM new_albumsales
# WHERE YEAR > 2020;

# #list going from 2010s to 2020
# SELECT *
# FROM new_albumsales
# ORDER BY YEAR ASC

# SELECT a.Artist,
# 	   a.Album,
# 	   a.Genre,
# 	   a.Year,
# 	   a."WorldwideSales(Est.)",
# 	b.GrammysWon, 
# 	b.Billboard200
	
# FROM new_albumSales a
# INNER JOIN grammys b
# 	ON a.Album = b.Album
# ORDER BY a.YEAR ASC;
