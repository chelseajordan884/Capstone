# %%
import pandas as pd
album_sales = pd.read_csv('albumsales.csv')

album_sales.info()
print(album_sales)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    640 non-null    int64
#  1   Artist                  640 non-null    object
#  2   Album                   640 non-null    object
#  3   Worldwide Sales (Est.)  640 non-null    object
#  4   Genre                   640 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 25.1+ KB
#      Year                   Artist                                   Album  \
# 0    2019                   Arashi           5x20 All The Best!! 1999-2019
# 1    2017               Elton John                                Diamonds
# 2    1995          Michael Jackson  History: Past, Present & Future Book I
# 3    2015      Broadway Soundtrack                                Hamilton
# ...

# %%
# SQL 
# SELECT 
# 	"Year", 
# 	"Album", 
# 	"WorldwideSales(Est.)"
# From albumsales
# ORDER BY YEAR ASC

#Deleting rows from before 2010
# DELETE 
# FROM albumsales
# WHERE YEAR < 2010;

# DELETE
# FROM albumsales
# WHERE YEAR > 2020;

# #list going from 2010s to 2020
# SELECT *
# FROM albumsales
# ORDER BY YEAR ASC

# %%
import pandas as pd
import sqlite3


con = sqlite3.connect('./sqlalbumsales.db')
album_sales = pd.read_sql_query('Select * from albumsales Order by Year ASC', con)

album_sales
# Out:
#      Year        Artist                              Album  \
# 0    2010        Eminem                           Recovery
# 1    2010    Kanye West  My Beautiful Dark Twisted Fantasy
# 2    2010  Taylor Swift                          Speak Now
# 3    2010  Jason Aldean                     My Kinda Party
# 4    2010    Katy Perry                      Teenage Dream
# ..    ...           ...                                ...
# 215  2020           BTS                                 Be
# 216  2020  Taylor Swift                           Folklore
# 217  2020      Dua Lipa                   Future Nostalgia
# 218  2020     Blackpink                          The Album
# 219  2020    The Weeknd                        After House
#
#     WorldwideSales(Est.)    Genre
# 0              7,740,795  Hip Hop
# 1              3,588,000  Hip Hop
# 2              6,917,500  Country
# 3              4,115,000  Country
# 4             11,094,000      Pop
# ..                   ...      ...
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.title("Greatest Album of the 2010's", fontdict={'fontweight': 'bold', 'fontsize':14})


plt.plot(album_sales.Year, album_sales.WorldWideSales(Est.), 'r.-', label=2010)

plt.
